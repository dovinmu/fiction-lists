# %%
from bs4 import BeautifulSoup
import re
import requests
import time

# %%
url = 'https://clarkesworldmagazine.com/prior/?y=2021'

# %%
r = requests.get(url)
soup = BeautifulSoup(r.text)

# %%
stories = set()
for table in soup.findAll('div', attrs={'class':'index-table'}):
    # if table doesn't contain a p tag with the words fiction, keep going
    section = table.find('p', attrs={'class': 'section'})
    if section is None or section.text.strip().lower() != 'fiction':
        continue
    for storydiv in table.findAll('div'):
#         print(storydiv.text)
        title = storydiv.find('p', attrs={'class':'story'})
        author = storydiv.find('p', attrs={'class':'byline'})
        if not title or not author:
            continue
        href = title.find('a').get('href')
        title = title.text.strip()
        author = author.text.replace('by', '').strip()
        stories.add((title, author, href))
stories
# Out:
# {('5,000 Words a Day: A Conversation with Cat Rambo',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/rambo_interview_2021'),
#  ('55 Plaque', 'Isabel Lee', 'https://clarkesworldmagazine.com/lee_03_21'),
#  ('A Brief History of Russian Science Fiction',
#   'Alex Shvartsman',
#   'https://clarkesworldmagazine.com/shvartsman_05_21'),
#  ("A Heist in Fifteen Products from the Orion Spur's Longest-Running Catalog",
#   'Andrea M. Pawley',
#   'https://clarkesworldmagazine.com/pawley_08_21'),
#  ('A Home for Mrs. Biswas',
#   'Amal Singh',
#   'https://clarkesworldmagazine.com/singh_05_21'),
#  ('A House Is Not A Home',
#   'L Chan',
#   'https://clarkesworldmagazine.com/chan_04_21'),
#  ('A Series of Endings',
#   'Amal Singh',
#   'https://clarkesworldmagazine.com/singh_12_21'),
#  ('A Star for Every Word Unspoken',
#   'Kai Hudson',
#   'https://clarkesworldmagazine.com/hudson_05_21'),
#  ('A Thousand Tiny Gods',
#   'Nadia Afifi',
#   'https://clarkesworldmagazine.com/afifi_08_21'),
#  ('A Universe of Possibilities: Planets of Red Dwarfs',
#   'Julie Nováková',
#   'https://clarkesworldmagazine.com/novakova_12_21'),
#  ('A Well-Worn Path',
#   'AnaMaria Curtis',
#   'https://clarkesworldmagazine.com/curtis_10_21'),
#  ('A Whole New Realm: A Conversation with Diana M. Pho',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/pho_interview'),
#  ('A Wider Range of Freedom: A Conversation with Alyssa Winans',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/winans_interview'),
#  ('An Instance',
#   'Mlok 5, translated  Julie Nováková',
#   'https://clarkesworldmagazine.com/mlok5_08_21'),
#  ("Aster's Partialities: Vitri's Best Store for Sundry Antiques",
#   'Tovah Strong',
#   'https://clarkesworldmagazine.com/strong_01_21'),
#  ('Beneath the Earth Where the Nymphs Sleep',
#   'Meghan Feldman',
#   'https://clarkesworldmagazine.com/feldman_12_21'),
#  ('Best-Laid Plans',
#   'David D. Levine',
#   'https://clarkesworldmagazine.com/levine_05_21'),
#  ('Between Zero and One There is Infinity',
#   'Shari Paul',
#   'https://clarkesworldmagazine.com/paul_11_21'),
#  ('Bots of the Lost Ark',
#   'Suzanne Palmer',
#   'https://clarkesworldmagazine.com/palmer_06_21'),
#  ('Breaking Out of the Box: A Conversation with Cadwell Turnbull',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/turnbull_interview'),
#  ('Candide; Life-',
#   'Beth Goder',
#   'https://clarkesworldmagazine.com/goder_08_21'),
#  ('Catching the K Beast',
#   'Chen Qian, translated  Carmen Yiling Yan',
#   'https://clarkesworldmagazine.com/chen_04_21'),
#  ('Celebrating the Diversity of Chinese Culture: A Conversation with Xueting Christine Ni',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/ni_interview'),
#  ('City of Eternity',
#   'Pan Haitian, translated  Carmen Yiling Yan',
#   'https://clarkesworldmagazine.com/pan_11_21'),
#  ('Comments on Your Provisional Patent Application for an Eternal Spirit Core',
#   'Wole Talabi',
#   'https://clarkesworldmagazine.com/talabi_03_21'),
#  ('Communist Computer Rap God',
#   'Andrea Kriz',
#   'https://clarkesworldmagazine.com/kriz_04_21'),
#  ('Companion',
#   'Derek Stenning',
#   'https://clarkesworldmagazine.com/artbio_177'),
#  ('Connected to Culture: A Conversation with Sheree Renée Thomas',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/thomas_interview'),
#  ('Culture Beyond Flair: A Conversation with S. Qiouyi Lu',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/lu_interview'),
#  ('Dancing With Ereshkigal',
#   'Sameem Siddiqui',
#   'https://clarkesworldmagazine.com/siddiqui_05_21'),
#  ('Dark Waters Still Flow',
#   'Alice Towey',
#   'https://clarkesworldmagazine.com/towey_11_21'),
#  ('Deep Music', 'Elly Bangs', 'https://clarkesworldmagazine.com/bangs_01_21'),
#  ('Destination Mercury',
#   'Andrew Liptak',
#   'https://clarkesworldmagazine.com/liptak_07_21'),
#  ('Dog and Pony Show',
#   'Robert Jeschonek',
#   'https://clarkesworldmagazine.com/jeschonek_09_21'),
#  ("Editor's Desk: 2020 Reader's Poll Finalists",
#   'Neil Clarke',
#   'https://clarkesworldmagazine.com/clarke_02_21'),
#  ("Editor's Desk: 2020 in Review",
#   'Neil Clarke',
#   'https://clarkesworldmagazine.com/clarke_01_21'),
#  ("Editor's Desk: A Quarantine Soapbox",
#   'Neil Clarke',
#   'https://clarkesworldmagazine.com/clarke_05_21'),
#  ("Editor's Desk: An In-House Holiday",
#   'Neil Clarke',
#   'https://clarkesworldmagazine.com/clarke_07_21'),
#  ("Editor's Desk: Changing the Conventional Wisdom",
#   'Neil Clarke',
#   'https://clarkesworldmagazine.com/clarke_11_21'),
#  ("Editor's Desk: Fifteen",
#   'Neil Clarke',
#   'https://clarkesworldmagazine.com/clarke_10_21'),
#  ("Editor's Desk: In the Months Ahead",
#   'Neil Clarke',
#   'https://clarkesworldmagazine.com/clarke_04_21'),
#  ("Editor's Desk: No Solicitations",
#   'Neil Clarke',
#   'https://clarkesworldmagazine.com/clarke_08_21'),
#  ("Editor's Desk: Ten+ Years of Translation",
#   'Neil Clarke',
#   'https://clarkesworldmagazine.com/clarke_09_21'),
#  ("Editor's Desk: The Best from 2020",
#   'Neil Clarke',
#   'https://clarkesworldmagazine.com/clarke_03_21'),
#  ("Editor's Desk: What Do You Want?",
#   'Neil Clarke',
#   'https://clarkesworldmagazine.com/clarke_06_21'),
#  ("Editor's Desk: Worldcon Bound",
#   'Neil Clarke',
#   'https://clarkesworldmagazine.com/clarke_12_21'),
#  ('Embracing the Movement',
#   'Cristina Jurado',
#   'https://clarkesworldmagazine.com/jurado_06_21'),
#  ('Excerpts from the Text of an Explanatory Stele Erected for Our Edification by the Scholars of the Outer Orion Tendril',
#   'Timons Esaias',
#   'https://clarkesworldmagazine.com/esaias_09_21'),
#  ('Explicit Queerness: A Conversation with Charlie Jane Anders',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/anders_interview_2021'),
#  ('Face Changing',
#   'Jiang Bo, translated  Andy Dudak',
#   'https://clarkesworldmagazine.com/jiang_06_21'),
#  ('Falling in Love and the Collective Consciousness: An Interview with Elly Bangs',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/bangs_interview'),
#  ('Forward', 'Wenjuinn Png', 'https://clarkesworldmagazine.com/artbio_173'),
#  ('Freedom Over Tyranny: A Conversation with Harry Turtledove',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/turtledove_interview'),
#  ('Fungi in Fiction',
#   'Carrie Sessarego',
#   'https://clarkesworldmagazine.com/sessarego_06_21'),
#  ("GUYS! Don't Lose Hope",
#   'JC Jongwon Park',
#   'https://clarkesworldmagazine.com/artbio_175'),
#  ('Garden',
#   'Alejandro Burdisio',
#   'https://clarkesworldmagazine.com/artbio_178'),
#  ('He Leaps for the Stars, He Leaps for the Stars',
#   'Grace Chan',
#   'https://clarkesworldmagazine.com/chan_07_21'),
#  ('History in Pieces',
#   'Beth Goder',
#   'https://clarkesworldmagazine.com/goder_02_21'),
#  ('Homecoming is Just Another Word for the Sublimation of the Self',
#   'Isabel J. Kim',
#   'https://clarkesworldmagazine.com/kim_03_21'),
#  ("I'm Feeling Lucky",
#   'Leonid Kaganov, translated  Alex Shvartsman',
#   'https://clarkesworldmagazine.com/kaganov_07_21'),
#  ('Important Strangers: A Conversation with Becky Chambers',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/chambers_interview'),
#  ('In a Net I Seek to Hold the Wind',
#   'Gregory Feeley',
#   'https://clarkesworldmagazine.com/feeley_09_21'),
#  ('In the Absence of Guidelines or Censorship: An Interview with Bo-Young Kim',
#   'Gord Sellar and Jihyun Park',
#   'https://clarkesworldmagazine.com/bo-young_interview'),
#  ('Intentionalities',
#   'Aimee Ogden',
#   'https://clarkesworldmagazine.com/ogden_01_21'),
#  ('Isolation', 'Matt Dixon', 'https://clarkesworldmagazine.com/artbio_176'),
#  ('It is a Pleasure to Receive You',
#   'Ziggy Schutz',
#   'https://clarkesworldmagazine.com/schutz_09_21'),
#  ('Just One Step, and Then the Next',
#   'E. N. Díaz',
#   'https://clarkesworldmagazine.com/diaz_12_21'),
#  ('Just Under the Threshold: A Conversation with Adrian Tchaikovsky',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/tchaikovsky_interview'),
#  ('Last Nice Day',
#   'Rich Larson',
#   'https://clarkesworldmagazine.com/larson_07_21'),
#  ('Leaving Room for the Moon',
#   'P H Lee',
#   'https://clarkesworldmagazine.com/lee_01_21'),
#  ('Legend of the Giant',
#   'Fei Dao, translated  Ken Liu',
#   'https://clarkesworldmagazine.com/fei_10_21'),
#  ('Little Animals',
#   'Nancy Kress',
#   'https://clarkesworldmagazine.com/kress_06_21'),
#  ('Little Town',
#   'Alejandro Burdisio',
#   'https://clarkesworldmagazine.com/artbio_179'),
#  ('Love Unflinching, at Low- to Zero-G',
#   'M. L. Clark',
#   'https://clarkesworldmagazine.com/clark_10_21'),
#  ("Mamaborg's Milk and the Brilliance of Gems",
#   'D.A. Xiaolin Spires',
#   'https://clarkesworldmagazine.com/spires_03_21'),
#  ('Mercy and the Mollusc',
#   'M. L. Clark',
#   'https://clarkesworldmagazine.com/clark_02_21'),
#  ('Mermay 2021',
#   'Alexander Thümler',
#   'https://clarkesworldmagazine.com/artbio_181'),
#  ('Mom Heart',
#   'Will McIntosh',
#   'https://clarkesworldmagazine.com/mcintosh_11_21'),
#  ('Navigating the Seas of South Asian Diversity: A Conversation with Tarun K. Saint',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/saint_interview'),
#  ('Navigating the Storms of the Mind',
#   'Douglas F. Dluzen',
#   'https://clarkesworldmagazine.com/dluzen_11_21'),
#  ('Obelisker Adrift in the Desert',
#   'K.H. Meridian',
#   'https://clarkesworldmagazine.com/meridian_02_21'),
#  ('Other Stories',
#   'Wang Yuan, translated  Andy Dudak',
#   'https://clarkesworldmagazine.com/wang_12_21'),
#  ('Our Fate, Told in Photons',
#   'K.W. Colyard',
#   'https://clarkesworldmagazine.com/colyard_06_21'),
#  ('Ouroboros',
#   'Dean-Paul Stephens',
#   'https://clarkesworldmagazine.com/stephens_04_21'),
#  ('Paper of Elephants',
#   'Brenda Cooper',
#   'https://clarkesworldmagazine.com/cooper_10_21'),
#  ('Perpetual Training: An Interview with Tommy Arnold',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/arnold_interview'),
#  ('Peter Pan Through the Years',
#   'Carrie Sessarego',
#   'https://clarkesworldmagazine.com/sessarego_02_21'),
#  ('Philia, Eros, Storge, Agápe, Pragma',
#   'R.S.A. Garcia',
#   'https://clarkesworldmagazine.com/garcia_01_21'),
#  ('Poubelle', 'Robert Reed', 'https://clarkesworldmagazine.com/reed_06_21'),
#  ('Preserved in Amber',
#   'Samantha Murray',
#   'https://clarkesworldmagazine.com/murray_07_21'),
#  ('Promises We Made Under A Brick-Dark Sky',
#   'Karen Osborne',
#   'https://clarkesworldmagazine.com/osborne_07_21'),
#  ('Rain Falling in the Pines',
#   'Lavie Tidhar',
#   'https://clarkesworldmagazine.com/tidhar_10_21'),
#  ('Raising Science Fictional Children: A Conversation with Kelly Robson',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/robson_interview'),
#  ('Resistance in a Drop of DNA',
#   'Andrea Kriz',
#   'https://clarkesworldmagazine.com/kriz_08_21'),
#  ('Retro Heroines: Bella, Buffy, and Katniss',
#   'Carrie Sessarego',
#   'https://clarkesworldmagazine.com/sessarego_08_21'),
#  ('Sarcophagus',
#   'Ray Nayler',
#   'https://clarkesworldmagazine.com/nayler_04_21'),
#  ('Science Fiction and Schmaltz: A Conversation with Connie Willis',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/willis_interview'),
#  ('Science, Math, Fiction, and the Oxford Comma: A Conversation with S.B. Divya',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/divya_interview'),
#  ('Space Cadet',
#   'Pascal Blanché',
#   'https://clarkesworldmagazine.com/artbio_182'),
#  ('Spore',
#   'Tang Fei, translated  Andy Dudak',
#   'https://clarkesworldmagazine.com/tang_05_21'),
#  ('Submergence',
#   'Arula Ratnakar',
#   'https://clarkesworldmagazine.com/ratnakar_03_21'),
#  ('Sunrise', 'Alex Ries', 'https://clarkesworldmagazine.com/artbio_174'),
#  ('Suspire', 'Yuumei', 'https://clarkesworldmagazine.com/artbio_172'),
#  ('Terra Rasa',
#   'Anastasia Bookreyeva, translated  Ray Nayler',
#   'https://clarkesworldmagazine.com/bookreyeva_02_21'),
#  ('The Answer Was Snails',
#   'Bo Balder',
#   'https://clarkesworldmagazine.com/balder_10_21'),
#  ('The Clock, Having Seen Its Face in the Mirror, Still Knows Not the Hour',
#   'Adam Stemple',
#   'https://clarkesworldmagazine.com/stemple_08_21'),
#  ('The Cold Calculations',
#   'Aimee Ogden',
#   'https://clarkesworldmagazine.com/ogden_12_21'),
#  ('The Cost of Doing Good: A Conversation with Octavia Cade',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/cade_interview'),
#  ('The Death Haiku of the Azure Five',
#   'L Chan',
#   'https://clarkesworldmagazine.com/chan_11_21'),
#  ('The Failed Dianas',
#   'Monique Laban',
#   'https://clarkesworldmagazine.com/laban_02_21'),
#  ('The Falling',
#   'M V Melcer',
#   'https://clarkesworldmagazine.com/melcer_07_21'),
#  ('The Field Tiger',
#   'Endria Isa Richardson',
#   'https://clarkesworldmagazine.com/richardson_04_21'),
#  ('The Force Exerted on the Mass of a Body',
#   'Bo Balder',
#   'https://clarkesworldmagazine.com/balder_05_21'),
#  ('The Freedom of Science Fiction: A Conversation with Tobias S. Buckell',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/buckell_interview_2021'),
#  ('The Language Birds Speak',
#   'Rebecca Campbell',
#   'https://clarkesworldmagazine.com/campbell_11_21'),
#  ('The Last Civilian',
#   'R. P. Sand',
#   'https://clarkesworldmagazine.com/sand_01_21'),
#  ('The Mermaid Problem',
#   'Carrie Sessarego',
#   'https://clarkesworldmagazine.com/sessarego_10_21'),
#  ('The Orbiting Guan Erye',
#   'Wang Zhenzhen, translated  Carmen Yiling Yan',
#   'https://clarkesworldmagazine.com/wang_03_21'),
#  ('The Practice of Writing: A Conversation with Nina Allan',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/allan_interview'),
#  ('The Serpentine Band',
#   "Congyun 'Mu Ming' Gu, translated  Tian Huang",
#   'https://clarkesworldmagazine.com/gu_08_21'),
#  ('The Sheen of Her Carapace',
#   'Richard Webb',
#   'https://clarkesworldmagazine.com/webb_04_21'),
#  ('The Shroud for the Mourners',
#   'Yukimi Ogawa',
#   'https://clarkesworldmagazine.com/ogawa_06_21'),
#  ('The Ten-Year Journey: A Conversation with E. Lily Yu',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/yu_interview'),
#  ('The Variable Man',
#   'Douglas P. Lobo',
#   'https://clarkesworldmagazine.com/artbio_183'),
#  ('The Winter Garden',
#   'Regina Kanyu Wang, translated  Emily Jin',
#   'https://clarkesworldmagazine.com/wang_09_21'),
#  ('This Stitch, This Time',
#   'Anna Martino',
#   'https://clarkesworldmagazine.com/martino_11_21'),
#  ('Thrilling to the Harmony: A Conversation with Karen Osborne',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/osborne_interview'),
#  ('Through',
#   'Eric Fomley and Rich Larson',
#   'https://clarkesworldmagazine.com/fomley_larson_10_21'),
#  ('To Study the Old Masters in the Prado at the End of the World',
#   'Sarah Pauling',
#   'https://clarkesworldmagazine.com/pauling_03_21'),
#  ("Under Pressure: Life's Last Dance?",
#   'Julie Nováková',
#   'https://clarkesworldmagazine.com/novakova_09_21'),
#  ('Undoing Good Women: A Conversation with Cassandra Khaw',
#   'Arley Sorg',
#   'https://clarkesworldmagazine.com/khaw_interview'),
#  ('Vanishing Point',
#   'Robert V.S. Redick',
#   'https://clarkesworldmagazine.com/redick_05_21'),
#  ('Vegvísir',
#   'David Goodman',
#   'https://clarkesworldmagazine.com/goodman_12_21'),
#  ('Vimana', 'Daniele Gay', 'https://clarkesworldmagazine.com/artbio_180'),
#  ('Wagon Train to the Arctic',
#   'Andrew Liptak',
#   'https://clarkesworldmagazine.com/liptak_04_21'),
#  ("We'll Always Have Two Versions of Pteros",
#   'Dominica Phetteplace',
#   'https://clarkesworldmagazine.com/phetteplace_02_21'),
#  ("We'll Know It When We See It: The Trouble with Finding (Alien) Life",
#   'Julie Nováková',
#   'https://clarkesworldmagazine.com/novakova_03_21'),
#  ('When the Sheaves Are Gathered',
#   'Nick Wolven',
#   'https://clarkesworldmagazine.com/wolven_07_21'),
#  ('Xiaolongbao: Soup Dumplings',
#   'D.A. Xiaolin Spires',
#   'https://clarkesworldmagazine.com/spires_09_21'),
#  ("Yesterday's Wolf",
#   'Ray Nayler',
#   'https://clarkesworldmagazine.com/nayler_09_21'),
#  ('You Are Born Exploding',
#   'Rich Larson',
#   'https://clarkesworldmagazine.com/larson_12_21'),
#  ('“Remember The Washington,” They Said as They Fed the Ugoxli',
#   'Jeff Reynolds',
#   'https://clarkesworldmagazine.com/reynolds_02_21')}

# %%
from output import write_list
write_list('clarkesworld-2021-shorts.md', stories)
